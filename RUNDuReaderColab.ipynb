# %% [markdown]
# # 系统环境

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Jan  1 10:54:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    23W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.7 gigabytes of available RAM
#
# To enable a high-RAM runtime, select the Runtime > "Change runtime type"
# menu, and then select High-RAM in the Runtime shape dropdown. Then,
# re-execute this cell.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 数据准备

# %%
# !mkdir ./dureader
# !cp ./drive/MyDrive/DuReader/DuReader.zip ./dureader
# !unzip ./dureader/DuReader.zip -d ./dureader
# !rm ./dureader/DuReader.zip
# Out:
# Archive:  ./dureader/DuReader.zip
#    creating: ./dureader/data/
#   inflating: ./dureader/data/dev-v1.1.json
#   inflating: ./dureader/data/test.json
#   inflating: ./dureader/data/test2.json
#   inflating: ./dureader/data/train-v1.1.json
#   inflating: ./dureader/ensemble.py
#   inflating: ./dureader/ensemble.sh
#    creating: ./dureader/ensemble_results/
#   inflating: ./dureader/ensemble_results/nbest_predictions_.json
#   inflating: ./dureader/ensemble_results/predictions_.json
#   inflating: ./dureader/eval_albert.sh
#   inflating: ./dureader/eval_ckp_bert.sh
#   inflating: ./dureader/eval_ckp_roberta.sh
#   inflating: ./dureader/eval_ckp_roberta_large.sh
#   inflating: ./dureader/eval_ckp_roberta_large2.sh
#   inflating: ./dureader/eval_ckp_roberta_large_brightmart.sh
#   inflating: ./dureader/eval_ensemble_model.sh
#   inflating: ./dureader/evaluate.py
#   inflating: ./dureader/main.py
#   inflating: ./dureader/predict.sh
#   inflating: ./dureader/process.py
# ...

# %%
# !touch ./dureader/download.sh

# %%
# !cp /content/drive/MyDrive/DuReader/download.sh ./dureader

# %%
# !sh ./dureader/download.sh

# %% [markdown]
# # 预训练模型

# %%
# !mkdir ./dureader/pretrained_model
# !mkdir ./dureader/output

# %% [markdown]
# ## roberta-base

# %%
# !mkdir ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch
# !mkdir ./dureader/output/chinese_roberta_wwm_ext_pytorch

# %%
# !cp ./drive/MyDrive/DuReader/chinese_roberta_wwm_ext_pytorch.zip ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch
# !unzip ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/chinese_roberta_wwm_ext_pytorch.zip -d ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch
# !rm ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/chinese_roberta_wwm_ext_pytorch.zip
# Out:
# Archive:  ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/chinese_roberta_wwm_ext_pytorch.zip
#   inflating: ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/vocab.txt
#   inflating: ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/bert_config.json
#   inflating: ./dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch/pytorch_model.bin

# %% [markdown]
# ## bert-base

# %%
# !mkdir ./dureader/pretrained_model/chinese_wwm_ext_pytorch
# !mkdir ./dureader/output/chinese_wwm_ext_pytorch

# %%
# !cp ./drive/MyDrive/DuReader/chinese_wwm_ext_pytorch.zip ./dureader/pretrained_model/chinese_wwm_ext_pytorch
# !unzip ./dureader/pretrained_model/chinese_wwm_ext_pytorch/chinese_wwm_ext_pytorch.zip -d ./dureader/pretrained_model/chinese_wwm_ext_pytorch
# !rm ./dureader/pretrained_model/chinese_wwm_ext_pytorch/chinese_wwm_ext_pytorch.zip
# Out:
# Archive:  ./dureader/pretrained_model/chinese_wwm_ext_pytorch/chinese_wwm_ext_pytorch.zip
#   inflating: ./dureader/pretrained_model/chinese_wwm_ext_pytorch/bert_config.json
#   inflating: ./dureader/pretrained_model/chinese_wwm_ext_pytorch/pytorch_model.bin
#   inflating: ./dureader/pretrained_model/chinese_wwm_ext_pytorch/vocab.txt

# %%
# 暂时先不使用albert

# %% [markdown]
# ## nezha-base

# %%
# !mkdir ./dureader/pretrained_model/chinese_nezha_base
# !mkdir ./dureader/output/chinese_nezha_base

# %%
# !cp ./drive/MyDrive/DuReader/chinese_nezha_base_pytorch.zip ./dureader/pretrained_model/chinese_nezha_base
# !unzip ./dureader/pretrained_model/chinese_nezha_base/chinese_nezha_base_pytorch.zip -d ./dureader/pretrained_model/chinese_nezha_base
# !rm ./dureader/pretrained_model/chinese_nezha_base/chinese_nezha_base_pytorch.zip
# Out:
# Archive:  ./dureader/pretrained_model/chinese_nezha_base/chinese_nezha_base_pytorch.zip
#   inflating: ./dureader/pretrained_model/chinese_nezha_base/config.json
#   inflating: ./dureader/pretrained_model/chinese_nezha_base/pytorch_model.bin
#   inflating: ./dureader/pretrained_model/chinese_nezha_base/vocab.txt

# %%
# !cp ./dureader/pretrained_model/chinese_albert_xlarge/albert_base/checkpoint ./dureader/pretrained_model/chinese_albert_xlarge
# !cp ./dureader/pretrained_model/chinese_albert_xlarge/albert_base/config.json ./dureader/pretrained_model/chinese_albert_xlarge
# !cp ./dureader/pretrained_model/chinese_albert_xlarge/albert_base/pytorch_model.bin ./dureader/pretrained_model/chinese_albert_xlarge
# !cp ./dureader/pretrained_model/chinese_albert_xlarge/albert_base/vocab.txt ./dureader/pretrained_model/chinese_albert_xlarge

# %%
# !rm -rf ./dureader/pretrained_model/chinese_albert_xlarge/albert_base/

# %% [markdown]
# ## ernie-base

# %%
# !mkdir ./dureader/pretrained_model/chinese_ernie_base
# !mkdir ./dureader/output/chinese_ernie_base

# %%
# !cp ./drive/MyDrive/DuReader/chinese_ernie_base_pytorch.zip ./dureader/pretrained_model/chinese_ernie_base
# !unzip ./dureader/pretrained_model/chinese_ernie_base/chinese_ernie_base_pytorch.zip -d ./dureader/pretrained_model/chinese_ernie_base
# !rm ./dureader/pretrained_model/chinese_ernie_base/chinese_ernie_base_pytorch.zip
# Out:
# Archive:  ./dureader/pretrained_model/chinese_ernie_base/chinese_ernie_base_pytorch.zip
#   inflating: ./dureader/pretrained_model/chinese_ernie_base/config.json
#   inflating: ./dureader/pretrained_model/chinese_ernie_base/pytorch_model.bin
#   inflating: ./dureader/pretrained_model/chinese_ernie_base/vocab.txt

# %% [markdown]
# # 安装依赖库

# %%
# !pip install transformers==3.4.0
# !pip install boto3
# !pip install apex
# Out:
# ...
#      |████████████████████████████████| 1.3MB 12.8MB/s
# ...
#      |████████████████████████████████| 890kB 49.4MB/s
# ...
#      |████████████████████████████████| 2.9MB 47.6MB/s
# ...
#      |████████████████████████████████| 1.1MB 47.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=40b2db3496b8ce33c7316eaffb76f964e0d706a71f816b23cb47cbe40ac452fe
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 102kB 7.6MB/s
# ...
#      |████████████████████████████████| 7.2MB 20.4MB/s
# ...
#      |████████████████████████████████| 71kB 9.8MB/s
# ...
#      |████████████████████████████████| 143kB 54.2MB/s
# ...
#   Created wheel for boto3: filename=boto3-1.16.47-py2.py3-none-any.whl size=128711 sha256=00826dcc4ae3e7457770e829330a6d4104106f045913ac1f787cbef2d9fc7eb3
# ...

# %% [markdown]
# # 模型训练与评估

# %% [markdown]
# ## roberta-base

# %% [markdown]
# ### training

# %%
# !touch ./dureader/run_chinese_roberta_wwm_ext_pytorch.sh

# %%
# !cp ./drive/MyDrive/DuReader/run_chinese_roberta_wwm_ext_pytorch.sh ./dureader

# %%
  # "model_type": "bert",
  # "gru_layers": 1,
  # "gru_hidden_size": 192,

# %%
# !cat ./dureader/run_chinese_roberta_wwm_ext_pytorch.sh
# Out:
# export PYTHONIOENCODING=utf-8
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CUDA_VISIBLE_DEVICES=0
# export OUTPUT_DIR=/content/dureader/output/chinese_roberta_wwm_ext_pytorch
# export MODEL_NAME_OR_PATH=/content/dureader/pretrained_model/chinese_roberta_wwm_ext_pytorch
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME_OR_PATH \
#                                  --do_train --data_dir=$DATA_DIR \
#                                  --max_seq_length 256 \
#                                  --per_gpu_train_batch_size 16 \
#                                  --gradient_accumulation_steps 2 \
#                                  --do_lower_case --learning_rate 2e-5 \
#                                  --num_train_epochs 3.0 \
#                                  --output_dir $OUTPUT_DIR/$TASK_NAME/ \
#                                  --save_steps 1000 \
# ...

# %%
# !sh ./dureader/run_chinese_roberta_wwm_ext_pytorch.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:   5% 82/1643 [00:28<09:04,  2.87it/s]
# Iteration:   5% 83/1643 [00:28<08:51,  2.94it/s]
# Iteration:   5% 84/1643 [00:29<09:03,  2.87it/s]
# Iteration:   5% 85/1643 [00:29<08:50,  2.94it/s]
# Iteration:   5% 86/1643 [00:29<09:02,  2.87it/s]
# Iteration:   5% 87/1643 [00:30<08:50,  2.94it/s]
# Iteration:   5% 88/1643 [00:30<09:05,  2.85it/s]
# Iteration:   5% 89/1643 [00:30<08:51,  2.93it/s]
# Iteration:   5% 90/1643 [00:31<09:02,  2.86it/s]
# Iteration:   6% 91/1643 [00:31<08:49,  2.93it/s]
# Iteration:   6% 92/1643 [00:31<09:04,  2.85it/s]
# Iteration:   6% 93/1643 [00:32<08:49,  2.92it/s]
# Iteration:   6% 94/1643 [00:32<09:04,  2.84it/s]
# Iteration:   6% 95/1643 [00:32<08:50,  2.92it/s]
# Iteration:   6% 96/1643 [00:33<09:02,  2.85it/s]
# Iteration:   6% 97/1643 [00:33<08:48,  2.93it/s]
# Iteration:   6% 98/1643 [00:33<08:58,  2.87it/s]
# Iteration:   6% 99/1643 [00:34<08:44,  2.94it/s]
# Iteration:   6% 100/1643 [00:34<08:57,  2.87it/s]
# ...

# %% [markdown]
# ### evaluate

# %%
# !touch ./dureader/eval_chinese_roberta_wwm_ext_pytorch.sh

# %%
# !cp ./drive/MyDrive/DuReader/eval_chinese_roberta_wwm_ext_pytorch.sh ./dureader

# %%
# !cat ./dureader/eval_chinese_roberta_wwm_ext_pytorch.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CHECKPOINT=checkpoint-2000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# export MODEL_NAME=dureader/output/chinese_roberta_wwm_ext_pytorch
# # FileNotFoundError: [Errno 2] No such file or directory: '/content/dureader//content/dureader/output/chinese_roberta_wwm_ext_pytorch/DuReader/predictions_.json'
# # [squad_metrics.py:431] Writing predictions to: .//content/dureader/output/chinese_roberta_wwm_ext_pytorch/DuReader/predictions_.json
# export PRED_FILE=$MODEL_NAME/$TASK_NAME/predictions_.json
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME/$TASK_NAME/$CHECKPOINT \
#                                  --do_eval \
#                                  --do_lower_case \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --max_seq_length 256 \
# ...

# %%
# !sh ./dureader/eval_chinese_roberta_wwm_ext_pytorch.sh
# Out:
# 2020-12-23 07:31:15.767877: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-23:07:31:18,411 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-23:07:31:18,415 INFO     [configuration_utils.py:307] loading configuration file dureader/output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-23:07:31:18,415 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
# ...

# %%
# !cp ./dureader/eval_chinese_roberta_wwm_ext_pytorch.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# ## bert-base

# %% [markdown]
# ###  training

# %%
# !touch ./dureader/run_chinese_bert_wwm_ext_pytorch.sh

# %%
# !cp ./drive/MyDrive/DuReader/run_chinese_bert_wwm_ext_pytorch.sh ./dureader

# %%
# !cat ./dureader/run_chinese_bert_wwm_ext_pytorch.sh
# Out:
# export PYTHONIOENCODING=utf-8
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CUDA_VISIBLE_DEVICES=0
# export OUTPUT_DIR=/content/dureader/output/chinese_wwm_ext_pytorch
# export MODEL_NAME_OR_PATH=/content/dureader/pretrained_model/chinese_wwm_ext_pytorch
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME_OR_PATH \
#                                  --do_train --data_dir=$DATA_DIR \
#                                  --max_seq_length 256 \
#                                  --per_gpu_train_batch_size 16 \
#                                  --gradient_accumulation_steps 2 \
#                                  --do_lower_case --learning_rate 2e-5 \
#                                  --num_train_epochs 3.0 \
#                                  --output_dir $OUTPUT_DIR/$TASK_NAME/ \
#                                  --save_steps 1000 \
# ...

# %%
# !sh ./dureader/run_chinese_bert_wwm_ext_pytorch.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:   5% 80/1643 [00:27<09:04,  2.87it/s]
# Iteration:   5% 81/1643 [00:27<08:50,  2.95it/s]
# Iteration:   5% 82/1643 [00:28<09:02,  2.88it/s]
# Iteration:   5% 83/1643 [00:28<08:50,  2.94it/s]
# Iteration:   5% 84/1643 [00:28<09:03,  2.87it/s]
# Iteration:   5% 85/1643 [00:29<08:50,  2.94it/s]
# Iteration:   5% 86/1643 [00:29<09:06,  2.85it/s]
# Iteration:   5% 87/1643 [00:29<08:52,  2.92it/s]
# Iteration:   5% 88/1643 [00:30<09:02,  2.87it/s]
# Iteration:   5% 89/1643 [00:30<08:50,  2.93it/s]
# Iteration:   5% 90/1643 [00:31<09:06,  2.84it/s]
# Iteration:   6% 91/1643 [00:31<08:51,  2.92it/s]
# Iteration:   6% 92/1643 [00:31<09:02,  2.86it/s]
# Iteration:   6% 93/1643 [00:32<08:48,  2.93it/s]
# Iteration:   6% 94/1643 [00:32<09:01,  2.86it/s]
# Iteration:   6% 95/1643 [00:32<08:46,  2.94it/s]
# Iteration:   6% 96/1643 [00:33<08:58,  2.87it/s]
# Iteration:   6% 97/1643 [00:33<08:44,  2.95it/s]
# Iteration:   6% 98/1643 [00:33<08:56,  2.88it/s]
# ...

# %%
# !cp ./dureader/run_chinese_bert_wwm_ext_pytorch.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# ### evaluate

# %%
# !touch ./dureader/eval_chinese_bert_wwm_ext_pytorch.sh

# %%
# !cp ./drive/MyDrive/DuReader/eval_chinese_bert_wwm_ext_pytorch.sh ./dureader

# %%
# !cat ./dureader/eval_chinese_bert_wwm_ext_pytorch.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CHECKPOINT=checkpoint-2000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# export MODEL_NAME=dureader/output/chinese_wwm_ext_pytorch
# export PRED_FILE=$MODEL_NAME/$TASK_NAME/predictions_.json
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME/$TASK_NAME/$CHECKPOINT \
#                                  --do_eval \
#                                  --do_lower_case \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --max_seq_length 256 \
#                                  --data_dir=$DATA_DIR \
#                                  --output_dir ./$MODEL_NAME/$TASK_NAME/ \
#                                  --overwrite_cache \
#                                  --max_answer_length 30 \
#
# python /content/dureader/evaluate.py $DATA_DIR/$DATASET_FILE $PRED_FILE

# %%
# !sh ./dureader/eval_chinese_bert_wwm_ext_pytorch.sh
# Out:
# 2020-12-23 08:17:33.824796: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-23:08:17:36,565 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-23:08:17:36,566 INFO     [configuration_utils.py:307] loading configuration file dureader/output/chinese_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-23:08:17:36,566 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
# ...

# %%
# !cp ./dureader/eval_chinese_bert_wwm_ext_pytorch.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# ## nezha-base

# %% [markdown]
# ### training

# %%
# !touch ./dureader/run_chinese_nezha_base.sh

# %%
# !cat ./dureader/run_chinese_nezha_base.sh
# Out:
# export PYTHONIOENCODING=utf-8
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CUDA_VISIBLE_DEVICES=0
# export OUTPUT_DIR=/content/dureader/output/chinese_nezha_base
# export MODEL_NAME_OR_PATH=/content/dureader/pretrained_model/chinese_nezha_base
# python /content/dureader/main.py --model_type bert --model_name_or_path $MODEL_NAME_OR_PATH --do_train --data_dir=$DATA_DIR --max_seq_length 256 --per_gpu_train_batch_size 16 --gradient_accumulation_steps 2 --do_lower_case --learning_rate 2e-5 --num_train_epochs 3.0 --output_dir $OUTPUT_DIR/$TASK_NAME/ --save_steps 1000 --overwrite_output_dir --overwrite_cache --max_answer_length 30

# %%
# !sh ./dureader/run_chinese_nezha_base.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:   5% 74/1643 [00:25<09:04,  2.88it/s]
# Iteration:   5% 75/1643 [00:25<08:51,  2.95it/s]
# Iteration:   5% 76/1643 [00:26<09:04,  2.88it/s]
# Iteration:   5% 77/1643 [00:26<08:51,  2.95it/s]
# Iteration:   5% 78/1643 [00:26<09:03,  2.88it/s]
# Iteration:   5% 79/1643 [00:27<08:50,  2.95it/s]
# Iteration:   5% 80/1643 [00:27<09:08,  2.85it/s]
# Iteration:   5% 81/1643 [00:27<08:53,  2.93it/s]
# Iteration:   5% 82/1643 [00:28<09:07,  2.85it/s]
# Iteration:   5% 83/1643 [00:28<08:53,  2.93it/s]
# Iteration:   5% 84/1643 [00:28<09:05,  2.86it/s]
# Iteration:   5% 85/1643 [00:29<08:51,  2.93it/s]
# Iteration:   5% 86/1643 [00:29<09:01,  2.88it/s]
# Iteration:   5% 87/1643 [00:29<08:48,  2.95it/s]
# Iteration:   5% 88/1643 [00:30<09:02,  2.87it/s]
# Iteration:   5% 89/1643 [00:30<08:50,  2.93it/s]
# Iteration:   5% 90/1643 [00:31<09:04,  2.85it/s]
# Iteration:   6% 91/1643 [00:31<08:50,  2.93it/s]
# Iteration:   6% 92/1643 [00:31<09:01,  2.86it/s]
# ...

# %%
# !cp ./dureader/run_chinese_nezha_base.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# ### evaluate

# %%
# !touch ./dureader/eval_chinese_nezha_base.sh

# %%
# !cat ./dureader/eval_chinese_nezha_base.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CHECKPOINT=checkpoint-2000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# export MODEL_NAME=dureader/output/chinese_nezha_base
# export PRED_FILE=$MODEL_NAME/$TASK_NAME/predictions_.json
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME/$TASK_NAME/$CHECKPOINT \
#                                  --do_eval \
#                                  --do_lower_case \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --max_seq_length 256 \
#                                  --data_dir=$DATA_DIR \
#                                  --output_dir ./$MODEL_NAME/$TASK_NAME/ \
#                                  --overwrite_cache \
#                                  --max_answer_length 30 \
#
# python /content/dureader/evaluate.py $DATA_DIR/$DATASET_FILE $PRED_FILE

# %%
# !sh ./dureader/eval_chinese_nezha_base.sh
# Out:
# 2020-12-23 10:05:15.543334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-23:10:05:18,280 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-23:10:05:18,281 INFO     [configuration_utils.py:307] loading configuration file dureader/output/chinese_nezha_base/DuReader/checkpoint-2000/config.json
# 2020-12-23:10:05:18,281 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
# ...

# %%
# !cp ./dureader/eval_chinese_nezha_base.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# - 可以看出nezha-base的效果相较bert-base和roberta-base较差。

# %% [markdown]
# ## ernie-base

# %% [markdown]
# ### training

# %%
# !touch ./dureader/run_chinese_ernie_base.sh

# %%
# !cat ./dureader/run_chinese_ernie_base.sh
# Out:
# export PYTHONIOENCODING=utf-8
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CUDA_VISIBLE_DEVICES=0
# export OUTPUT_DIR=/content/dureader/output/chinese_ernie_base
# export MODEL_NAME_OR_PATH=/content/dureader/pretrained_model/chinese_ernie_base
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME_OR_PATH \
#                                  --do_train --data_dir=$DATA_DIR \
#                                  --max_seq_length 256 \
#                                  --per_gpu_train_batch_size 16 \
#                                  --gradient_accumulation_steps 2 \
#                                  --do_lower_case --learning_rate 2e-5 \
#                                  --num_train_epochs 3.0 \
#                                  --output_dir $OUTPUT_DIR/$TASK_NAME/ \
#                                  --save_steps 1000 \
#                                  --overwrite_output_dir \
# ...

# %%
# !sh ./dureader/run_chinese_ernie_base.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:   3% 47/1638 [00:15<08:51,  2.99it/s]
# Iteration:   3% 48/1638 [00:16<09:03,  2.93it/s]
# Iteration:   3% 49/1638 [00:16<08:51,  2.99it/s]
# Iteration:   3% 50/1638 [00:16<09:00,  2.94it/s]
# Iteration:   3% 51/1638 [00:17<08:48,  3.00it/s]
# Iteration:   3% 52/1638 [00:17<08:59,  2.94it/s]
# Iteration:   3% 53/1638 [00:17<08:47,  3.00it/s]
# Iteration:   3% 54/1638 [00:18<09:00,  2.93it/s]
# Iteration:   3% 55/1638 [00:18<08:48,  3.00it/s]
# Iteration:   3% 56/1638 [00:18<09:01,  2.92it/s]
# Iteration:   3% 57/1638 [00:19<08:49,  2.99it/s]
# Iteration:   4% 58/1638 [00:19<09:00,  2.92it/s]
# Iteration:   4% 59/1638 [00:19<08:48,  2.99it/s]
# Iteration:   4% 60/1638 [00:20<09:02,  2.91it/s]
# Iteration:   4% 61/1638 [00:20<08:48,  2.98it/s]
# Iteration:   4% 62/1638 [00:20<08:58,  2.93it/s]
# Iteration:   4% 63/1638 [00:21<08:46,  2.99it/s]
# Iteration:   4% 64/1638 [00:21<08:56,  2.93it/s]
# Iteration:   4% 65/1638 [00:21<08:44,  3.00it/s]
# ...

# %%
# !cp ./dureader/run_chinese_ernie_base.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# ### evaluate

# %%
# !touch ./dureader/eval_chinese_ernie_base.sh

# %%
# !cat ./dureader/eval_chinese_ernie_base.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CHECKPOINT=checkpoint-2000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# export MODEL_NAME=dureader/output/chinese_ernie_base
# export PRED_FILE=$MODEL_NAME/$TASK_NAME/predictions_.json
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME/$TASK_NAME/$CHECKPOINT \
#                                  --do_eval \
#                                  --do_lower_case \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --max_seq_length 256 \
#                                  --data_dir=$DATA_DIR \
#                                  --output_dir ./$MODEL_NAME/$TASK_NAME/ \
#                                  --overwrite_cache \
#                                  --max_answer_length 30 \
#
# python /content/dureader/evaluate.py $DATA_DIR/$DATASET_FILE $PRED_FILE

# %%
# !sh ./dureader/eval_chinese_ernie_base.sh
# Out:
# 2020-12-23 10:58:45.289501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-23:10:58:47,562 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-23:10:58:47,563 INFO     [configuration_utils.py:307] loading configuration file dureader/output/chinese_ernie_base/DuReader/checkpoint-2000/config.json
# 2020-12-23:10:58:47,564 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "relu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
# ...

# %%
# !cp ./dureader/eval_chinese_ernie_base.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# - 可以看出ERNIE的效果较nezha要好些，但是还是比bert和roberta差。

# %% [markdown]
# # 模型集成

# %% [markdown]
# - 综合上述结果，决定将bert和roberta以及ernie进行模型集成

# %%
# !cp ./dureader/ensemble.py ./drive/MyDrive/DuReader

# %%
# !touch ./dureader/ensemble_roberta_bert_ernie.sh

# %%
# !mkdir ./dureader/ensemble_roberta_bert_ernie_results

# %%
# !cat ./dureader/ensemble_roberta_bert_ernie.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# # export CHECKPOINT=checkpoint-3000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# # export MODEL_NAME=roberta_large_adv_output
# export PRED_FILE=/content/dureader/ensemble_roberta_bert_ernie_results/predictions_.json
# python /content/dureader/ensemble.py --model_type bert --do_eval --do_lower_case --max_seq_length 256 --data_dir=$DATA_DIR  --output_dir ./ensemble_results --max_answer_length 30 --overwrite_cache --overwrite_output --overwrite_output_dir
#
# python /content/dureader/evaluate.py $DATA_DIR/$DATASET_FILE $PRED_FILE

# %%
# 修改后ensemble.py

# %%
# !mkdir /content/dureader/
# !cp /content/drive/MyDrive/DuReader/dureader.zip /content/
# !unzip /content/dureader.zip -d /content/dureader
# !rm /content/dureader.zip
# Out:
# Archive:  /content/dureader.zip
#    creating: /content/dureader/.ipynb_checkpoints/
#    creating: /content/dureader/data/
#   inflating: /content/dureader/data/dev-v1.1.json
#   inflating: /content/dureader/data/test.json
#   inflating: /content/dureader/data/test2.json
#   inflating: /content/dureader/data/train-v1.1.json
#   inflating: /content/dureader/ensemble.py
#   inflating: /content/dureader/ensemble.sh
#    creating: /content/dureader/ensemble_results/
#   inflating: /content/dureader/ensemble_results/nbest_predictions_.json
#   inflating: /content/dureader/ensemble_results/predictions_.json
#   inflating: /content/dureader/ensemble_roberta_bert_ernie.sh
#    creating: /content/dureader/ensemble_roberta_bert_ernie_results/
#   inflating: /content/dureader/eval_chinese_bert_wwm_ext_pytorch.sh
#   inflating: /content/dureader/eval_chinese_ernie_base.sh
#   inflating: /content/dureader/eval_chinese_nezha_base.sh
# ...

# %%
# 修改后代码

# %%
# !sh ./dureader/ensemble_roberta_bert_ernie.sh
# Out:
# 2021-01-01 11:10:29.425218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-01:11:10:31,478 WARNING  [ensemble_2nd.py:651] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2021-01-01:11:10:31,480 INFO     [configuration_utils.py:307] loading configuration file /content/dureader/output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2021-01-01:11:10:31,480 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
# ...

# %%
# !cp ./dureader/ensemble_roberta_bert_ernie.sh ./drive/MyDrive/DuReader/

# %% [markdown]
# # 打包保存至Google Drive

# %%
# !cp -r /content/dureader/ /content/drive/MyDrive/DuReader/

# %% [markdown]
# # 直接在上次运行的环境内继续进行修改

# %%
# 解压环境至本地

# %%
# !mkdir /content/dureader/
# !cp /content/drive/MyDrive/DuReader/dureader.zip /content/
# !unzip /content/dureader.zip -d /content/dureader
# !rm /content/dureader.zip
# Out:
# Archive:  /content/dureader.zip
#    creating: /content/dureader/.ipynb_checkpoints/
#    creating: /content/dureader/data/
#   inflating: /content/dureader/data/dev-v1.1.json
#   inflating: /content/dureader/data/test.json
#   inflating: /content/dureader/data/test2.json
#   inflating: /content/dureader/data/train-v1.1.json
#   inflating: /content/dureader/ensemble.py
#   inflating: /content/dureader/ensemble.sh
#    creating: /content/dureader/ensemble_results/
#   inflating: /content/dureader/ensemble_results/nbest_predictions_.json
#   inflating: /content/dureader/ensemble_results/predictions_.json
#   inflating: /content/dureader/ensemble_roberta_bert_ernie.sh
#    creating: /content/dureader/ensemble_roberta_bert_ernie_results/
#   inflating: /content/dureader/eval_chinese_bert_wwm_ext_pytorch.sh
#   inflating: /content/dureader/eval_chinese_ernie_base.sh
#   inflating: /content/dureader/eval_chinese_nezha_base.sh
# ...

# %%
# 尝试使用chinese_wwm_pytorch的预训练语言模型

# %%
# !mkdir ./dureader/pretrained_model/chinese_wwm_pytorch
# !mkdir ./dureader/output/chinese_wwm_pytorch

# %%
# !cp ./drive/MyDrive/DuReader/chinese_wwm_pytorch.zip ./dureader/pretrained_model/chinese_wwm_pytorch
# !unzip ./dureader/pretrained_model/chinese_wwm_pytorch/chinese_wwm_pytorch.zip -d ./dureader/pretrained_model/chinese_wwm_pytorch
# !rm ./dureader/pretrained_model/chinese_wwm_pytorch/chinese_wwm_pytorch.zip
# Out:
# Archive:  ./dureader/pretrained_model/chinese_wwm_pytorch/chinese_wwm_pytorch.zip
#   inflating: ./dureader/pretrained_model/chinese_wwm_pytorch/bert_config.json
#   inflating: ./dureader/pretrained_model/chinese_wwm_pytorch/pytorch_model.bin
#   inflating: ./dureader/pretrained_model/chinese_wwm_pytorch/vocab.txt

# %%
# !touch ./dureader/run_chinese_wwm_pytorch.sh

# %%
# !cat ./dureader/run_chinese_wwm_pytorch.sh
# Out:
# export PYTHONIOENCODING=utf-8
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CUDA_VISIBLE_DEVICES=0
# export OUTPUT_DIR=/content/dureader/output/chinese_wwm_pytorch
# export MODEL_NAME_OR_PATH=/content/dureader/pretrained_model/chinese_wwm_pytorch
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME_OR_PATH \
#                                  --do_train --data_dir=$DATA_DIR \
#                                  --max_seq_length 256 \
#                                  --per_gpu_train_batch_size 16 \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --gradient_accumulation_steps 4 \
#                                  --do_lower_case \
#                                  --learning_rate 2e-5 \
#                                  --num_train_epochs 3.0 \
#                                  --output_dir $OUTPUT_DIR/$TASK_NAME/ \
# ...

# %%
# !nvidia-smi
# Out:
# Fri Dec 25 06:58:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    23W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !sh ./dureader/run_chinese_wwm_pytorch.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:   5% 79/1643 [00:27<08:48,  2.96it/s]
# Iteration:   5% 80/1643 [00:27<09:05,  2.86it/s]
# Iteration:   5% 81/1643 [00:27<08:55,  2.92it/s]
# Iteration:   5% 82/1643 [00:28<08:48,  2.95it/s]
# Iteration:   5% 83/1643 [00:28<08:46,  2.96it/s]
# Iteration:   5% 84/1643 [00:28<09:05,  2.86it/s]
# Iteration:   5% 85/1643 [00:29<08:55,  2.91it/s]
# Iteration:   5% 86/1643 [00:29<08:48,  2.94it/s]
# Iteration:   5% 87/1643 [00:29<08:43,  2.97it/s]
# Iteration:   5% 88/1643 [00:30<09:01,  2.87it/s]
# Iteration:   5% 89/1643 [00:30<08:52,  2.92it/s]
# Iteration:   5% 90/1643 [00:30<08:46,  2.95it/s]
# Iteration:   6% 91/1643 [00:31<08:44,  2.96it/s]
# Iteration:   6% 92/1643 [00:31<09:01,  2.86it/s]
# Iteration:   6% 93/1643 [00:31<08:51,  2.92it/s]
# Iteration:   6% 94/1643 [00:32<08:45,  2.95it/s]
# Iteration:   6% 95/1643 [00:32<08:42,  2.96it/s]
# Iteration:   6% 96/1643 [00:32<09:01,  2.86it/s]
# Iteration:   6% 97/1643 [00:33<08:52,  2.91it/s]
# ...

# %%
# 验证

# %%
# !touch ./dureader/eval_chinese_wwm_pytorch.sh

# %%
# !cat ./dureader/eval_chinese_wwm_pytorch.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# export CHECKPOINT=checkpoint-1000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# export MODEL_NAME=dureader/output/chinese_wwm_pytorch
# export PRED_FILE=$MODEL_NAME/$TASK_NAME/predictions_.json
# python /content/dureader/main.py --model_type bert \
#                                  --model_name_or_path $MODEL_NAME/$TASK_NAME/$CHECKPOINT \
#                                  --do_eval \
#                                  --do_lower_case \
#                                  --per_gpu_eval_batch_size 512 \
#                                  --max_seq_length 256 \
#                                  --data_dir=$DATA_DIR \
#                                  --output_dir ./$MODEL_NAME/$TASK_NAME/ \
#                                  --overwrite_cache \
#                                  --max_answer_length 30 \
#
# python /content/dureader/evaluate.py $DATA_DIR/$DATASET_FILE $PRED_FILE

# %%
# !sh ./dureader/eval_chinese_wwm_pytorch.sh
# Out:
# 2020-12-25 07:44:06.333162: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-25:07:44:08,461 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-25:07:44:08,462 INFO     [configuration_utils.py:307] loading configuration file dureader/output/chinese_wwm_pytorch/DuReader/checkpoint-1000/config.json
# 2020-12-25:07:44:08,462 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
# ...

# %%
# 再次进行集成

# %%
# !cat ./dureader/ensemble_roberta_bert_ernie.sh
# Out:
# export DATA_DIR=/content/dureader/data
# export TASK_NAME=DuReader
# # export CHECKPOINT=checkpoint-3000
# export CUDA_VISIBLE_DEVICES=0
# export DATASET_FILE=dev-v1.1.json
# # export MODEL_NAME=roberta_large_adv_output
# export PRED_FILE=/content/dureader/ensemble_roberta_bert_ernie_results/predictions_.json
# python /content/dureader/ensemble.py --model_type bert \
#                                      --do_eval \
#                                      --do_lower_case \
#                                      --max_seq_length 256 \
#                                      --data_dir=$DATA_DIR \
#                                      --per_gpu_eval_batch_size 512 \
#                                      --output_dir /content/dureader/ensemble_roberta_bert_ernie_results \
#                                      --max_answer_length 30 \
#                                      --overwrite_cache \
#                                      --overwrite_output \
# ...

# %%
# !sh ./dureader/ensemble_roberta_bert_ernie.sh
# Out:
# 2020-12-25 07:47:53.791700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-25:07:47:55,971 WARNING  [ensemble.py:590] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-25:07:47:55,974 INFO     [configuration_utils.py:307] loading configuration file /content/dureader/output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-25:07:47:55,975 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "gru_hidden_size": 192,
#   "gru_layers": 1,
#   "hidden_act": "gelu",
# ...

# %% [markdown]
# # 看起来，似乎集成后模型效果更差了

# %% [markdown]
# # 全部使用bert类模型就可以跑通集成代码，但是为什么换成ernie就不行呢？
